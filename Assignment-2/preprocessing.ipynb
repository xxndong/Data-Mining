# %%
from importlib import import_module
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv('jumlah-tenaga-kesehatan-menurut-kecamatan-2019.csv')
# print(dataset)

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -3].values

print("data X : ", X)
# print("data Y : ", y)

# Melakukan split dataset menjadi Training set dan Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Menghilangkan missing value
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imputer.fit(X)
X = imputer.transform(X)
# print(imputer.transform(X))

# Encoding data kategori
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1,2,3])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
print(X)

# Melakukan split dataset menjadi Training set dan Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
print("X_train : ", X_train)
print("X_test : ", X_test)
print("y_train : ", y_train)
print("y_test : ", y_test)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train[:, 5:] = sc.fit_transform(X_train[:, 5:].reshape(1, -1))
X_test[:, 5:] = sc.fit_transform(X_test[:, 5:].reshape(1, -1))
print(X_test)
print(X_train)
# Out:
# data X :  [[2019 'Kepulauan Seribu' 'KEPULAUAN SERIBU UTARA' 'dokter']
#  [2019 'Kepulauan Seribu' 'KEPULAUAN SERIBU SELATAN' 'dokter']
#  [2019 'Jakarta Selatan' 'CILANDAK' 'dokter']
#  [2019 'Jakarta Selatan' 'JAGAKARSA ' 'dokter']
#  [2019 'Jakarta Selatan' 'KEBAYORAN BARU' 'dokter']
#  [2019 'Jakarta Selatan' 'KEBAYORAN LAMA' 'dokter']
#  [2019 'Jakarta Selatan' 'MAMPANG PRAPATAN' 'dokter']
#  [2019 'Jakarta Selatan' 'PANCORAN' 'dokter']
#  [2019 'Jakarta Selatan' 'PASAR MINGGU' 'dokter']
#  [2019 'Jakarta Selatan' 'PESANGGRAHAN' 'dokter']
#  [2019 'Jakarta Selatan' 'SETIABUDI' 'dokter']
#  [2019 'Jakarta Selatan' 'TEBET' 'dokter']
#  [2019 'Jakarta Timur' 'JATINEGARA' 'dokter']
#  [2019 'Jakarta Timur' 'MATRAMAN' 'dokter']
#  [2019 'Jakarta Timur' 'PULOGADUNG' 'dokter']
#  [2019 'Jakarta Timur' 'CAKUNG' 'dokter']
#  [2019 'Jakarta Timur' 'DUREN SAWIT' 'dokter']
#  [2019 'Jakarta Timur' 'KRAMAT JATI' 'dokter']
#  [2019 'Jakarta Timur' 'MAKASAR' 'dokter']
#  [2019 'Jakarta Timur' 'CIPAYUNG' 'dokter']
#  [2019 'Jakarta Timur' 'PASAR REBO' 'dokter']
#  [2019 'Jakarta Timur' 'CIRACAS' 'dokter']
#  [2019 'Jakarta Pusat' 'Cempaka Putih' 'dokter']
#  [2019 'Jakarta Pusat' 'Johar Baru' 'dokter']
#  [2019 'Jakarta Pusat' 'Menteng' 'dokter']
#  [2019 'Jakarta Pusat' 'Tanah Abang' 'dokter']
#  [2019 'Jakarta Pusat' 'Kemayoran' 'dokter']
#  [2019 'Jakarta Pusat' 'Senen' 'dokter']
#  [2019 'Jakarta Pusat' 'Sawah Besar' 'dokter']
#  [2019 'Jakarta Pusat' 'Gambir' 'dokter']
#  [2019 'Jakarta Barat' 'KEMBANGAN' 'dokter']
#  [2019 'Jakarta Barat' 'KEBON JERUK' 'dokter']
#  [2019 'Jakarta Barat' 'PALMERAH' 'dokter']
#  [2019 'Jakarta Barat' 'GROGOL PETAMBURAN' 'dokter']
#  [2019 'Jakarta Barat' 'TAMBORA' 'dokter']
#  [2019 'Jakarta Barat' 'TAMAN SARI' 'dokter']
#  [2019 'Jakarta Barat' 'CENGKARENG' 'dokter']
#  [2019 'Jakarta Barat' 'KALIDERES' 'dokter']
#  [2019 'Jakarta Utara' 'Penjaringan' 'dokter']
#  [2019 'Jakarta Utara' 'Pademangan' 'dokter']
#  [2019 'Jakarta Utara' 'Tanjung Priok' 'dokter']
#  [2019 'Jakarta Utara' 'Koja' 'dokter']
#  [2019 'Jakarta Utara' 'Kelapa Gading' 'dokter']
#  [2019 'Jakarta Utara' 'Cilincing' 'dokter']
#  [2019 'Kepulauan Seribu' 'KEPULAUAN SERIBU UTARA' 'perawat']
#  [2019 'Kepulauan Seribu' 'KEPULAUAN SERIBU SELATAN' 'perawat']
#  [2019 'Jakarta Selatan' 'CILANDAK' 'perawat']
#  [2019 'Jakarta Selatan' 'JAGAKARSA ' 'perawat']
#  [2019 'Jakarta Selatan' 'KEBAYORAN BARU' 'perawat']
#  [2019 'Jakarta Selatan' 'KEBAYORAN LAMA' 'perawat']
#  [2019 'Jakarta Selatan' 'MAMPANG PRAPATAN' 'perawat']
#  [2019 'Jakarta Selatan' 'PANCORAN' 'perawat']
#  [2019 'Jakarta Selatan' 'PASAR MINGGU' 'perawat']
#  [2019 'Jakarta Selatan' 'PESANGGRAHAN' 'perawat']
#  [2019 'Jakarta Selatan' 'SETIABUDI' 'perawat']
#  [2019 'Jakarta Selatan' 'TEBET' 'perawat']
#  [2019 'Jakarta Timur' 'JATINEGARA' 'perawat']
#  [2019 'Jakarta Timur' 'MATRAMAN' 'perawat']
#  [2019 'Jakarta Timur' 'PULOGADUNG' 'perawat']
#  [2019 'Jakarta Timur' 'CAKUNG' 'perawat']
#  [2019 'Jakarta Timur' 'DUREN SAWIT' 'perawat']
#  [2019 'Jakarta Timur' 'KRAMAT JATI' 'perawat']
#  [2019 'Jakarta Timur' 'MAKASAR' 'perawat']
#  [2019 'Jakarta Timur' 'CIPAYUNG' 'perawat']
#  [2019 'Jakarta Timur' 'PASAR REBO' 'perawat']
#  [2019 'Jakarta Timur' 'CIRACAS' 'perawat']
#  [2019 'Jakarta Pusat' 'Cempaka Putih' 'perawat']
#  [2019 'Jakarta Pusat' 'Johar Baru' 'perawat']
#  [2019 'Jakarta Pusat' 'Menteng' 'perawat']
#  [2019 'Jakarta Pusat' 'Tanah Abang' 'perawat']
#  [2019 'Jakarta Pusat' 'Kemayoran' 'perawat']
#  [2019 'Jakarta Pusat' 'Senen' 'perawat']
#  [2019 'Jakarta Pusat' 'Sawah Besar' 'perawat']
#  [2019 'Jakarta Pusat' 'Gambir' 'perawat']
#  [2019 'Jakarta Barat' 'KEMBANGAN' 'perawat']
#  [2019 'Jakarta Barat' 'KEBON JERUK' 'perawat']
#  [2019 'Jakarta Barat' 'PALMERAH' 'perawat']
#  [2019 'Jakarta Barat' 'GROGOL PETAMBURAN' 'perawat']
#  [2019 'Jakarta Barat' 'TAMBORA' 'perawat']
#  [2019 'Jakarta Barat' 'TAMAN SARI' 'perawat']
#  [2019 'Jakarta Barat' 'CENGKARENG' 'perawat']
#  [2019 'Jakarta Barat' 'KALIDERES' 'perawat']
#  [2019 'Jakarta Utara' 'Penjaringan' 'perawat']
#  [2019 'Jakarta Utara' 'Pademangan' 'perawat']
#  [2019 'Jakarta Utara' 'Tanjung Priok' 'perawat']
#  [2019 'Jakarta Utara' 'Koja' 'perawat']
#  [2019 'Jakarta Utara' 'Kelapa Gading' 'perawat']
#  [2019 'Jakarta Utara' 'Cilincing' 'perawat']
#  [2019 'Kepulauan Seribu' 'KEPULAUAN SERIBU UTARA' 'bidan']
#  [2019 'Kepulauan Seribu' 'KEPULAUAN SERIBU SELATAN' 'bidan']
#  [2019 'Jakarta Selatan' 'CILANDAK' 'bidan']
#  [2019 'Jakarta Selatan' 'JAGAKARSA ' 'bidan']
#  [2019 'Jakarta Selatan' 'KEBAYORAN BARU' 'bidan']
#  [2019 'Jakarta Selatan' 'KEBAYORAN LAMA' 'bidan']
#  [2019 'Jakarta Selatan' 'MAMPANG PRAPATAN' 'bidan']
#  [2019 'Jakarta Selatan' 'PANCORAN' 'bidan']
#  [2019 'Jakarta Selatan' 'PASAR MINGGU' 'bidan']
#  [2019 'Jakarta Selatan' 'PESANGGRAHAN' 'bidan']
#  [2019 'Jakarta Selatan' 'SETIABUDI' 'bidan']
#  [2019 'Jakarta Selatan' 'TEBET' 'bidan']
#  [2019 'Jakarta Timur' 'JATINEGARA' 'bidan']
#  [2019 'Jakarta Timur' 'MATRAMAN' 'bidan']
#  [2019 'Jakarta Timur' 'PULOGADUNG' 'bidan']
#  [2019 'Jakarta Timur' 'CAKUNG' 'bidan']
#  [2019 'Jakarta Timur' 'DUREN SAWIT' 'bidan']
#  [2019 'Jakarta Timur' 'KRAMAT JATI' 'bidan']
#  [2019 'Jakarta Timur' 'MAKASAR' 'bidan']
#  [2019 'Jakarta Timur' 'CIPAYUNG' 'bidan']
#  [2019 'Jakarta Timur' 'PASAR REBO' 'bidan']
#  [2019 'Jakarta Timur' 'CIRACAS' 'bidan']
#  [2019 'Jakarta Pusat' 'Cempaka Putih' 'bidan']
#  [2019 'Jakarta Pusat' 'Johar Baru' 'bidan']
#  [2019 'Jakarta Pusat' 'Menteng' 'bidan']
#  [2019 'Jakarta Pusat' 'Tanah Abang' 'bidan']
#  [2019 'Jakarta Pusat' 'Kemayoran' 'bidan']
#  [2019 'Jakarta Pusat' 'Senen' 'bidan']
#  [2019 'Jakarta Pusat' 'Sawah Besar' 'bidan']
#  [2019 'Jakarta Pusat' 'Gambir' 'bidan']
#  [2019 'Jakarta Barat' 'KEMBANGAN' 'bidan']
#  [2019 'Jakarta Barat' 'KEBON JERUK' 'bidan']
#  [2019 'Jakarta Barat' 'PALMERAH' 'bidan']
#  [2019 'Jakarta Barat' 'GROGOL PETAMBURAN' 'bidan']
#  [2019 'Jakarta Barat' 'TAMBORA' 'bidan']
#  [2019 'Jakarta Barat' 'TAMAN SARI' 'bidan']
#  [2019 'Jakarta Barat' 'CENGKARENG' 'bidan']
#  [2019 'Jakarta Barat' 'KALIDERES' 'bidan']
#  [2019 'Jakarta Utara' 'Penjaringan' 'bidan']
#  [2019 'Jakarta Utara' 'Pademangan' 'bidan']
#  [2019 'Jakarta Utara' 'Tanjung Priok' 'bidan']
#  [2019 'Jakarta Utara' 'Koja' 'bidan']
#  [2019 'Jakarta Utara' 'Kelapa Gading' 'bidan']
#  [2019 'Jakarta Utara' 'Cilincing' 'bidan']
#  [2019 'Kepulauan Seribu' 'KEPULAUAN SERIBU UTARA' 'farmasi']
#  [2019 'Kepulauan Seribu' 'KEPULAUAN SERIBU SELATAN' 'farmasi']
#  [2019 'Jakarta Selatan' 'CILANDAK' 'farmasi']
#  [2019 'Jakarta Selatan' 'JAGAKARSA ' 'farmasi']
#  [2019 'Jakarta Selatan' 'KEBAYORAN BARU' 'farmasi']
#  [2019 'Jakarta Selatan' 'KEBAYORAN LAMA' 'farmasi']
#  [2019 'Jakarta Selatan' 'MAMPANG PRAPATAN' 'farmasi']
#  [2019 'Jakarta Selatan' 'PANCORAN' 'farmasi']
#  [2019 'Jakarta Selatan' 'PASAR MINGGU' 'farmasi']
#  [2019 'Jakarta Selatan' 'PESANGGRAHAN' 'farmasi']
#  [2019 'Jakarta Selatan' 'SETIABUDI' 'farmasi']
#  [2019 'Jakarta Selatan' 'TEBET' 'farmasi']
#  [2019 'Jakarta Timur' 'JATINEGARA' 'farmasi']
#  [2019 'Jakarta Timur' 'MATRAMAN' 'farmasi']
#  [2019 'Jakarta Timur' 'PULOGADUNG' 'farmasi']
#  [2019 'Jakarta Timur' 'CAKUNG' 'farmasi']
#  [2019 'Jakarta Timur' 'DUREN SAWIT' 'farmasi']
#  [2019 'Jakarta Timur' 'KRAMAT JATI' 'farmasi']
#  [2019 'Jakarta Timur' 'MAKASAR' 'farmasi']
#  [2019 'Jakarta Timur' 'CIPAYUNG' 'farmasi']
#  [2019 'Jakarta Timur' 'PASAR REBO' 'farmasi']
#  [2019 'Jakarta Timur' 'CIRACAS' 'farmasi']
#  [2019 'Jakarta Pusat' 'Cempaka Putih' 'farmasi']
#  [2019 'Jakarta Pusat' 'Johar Baru' 'farmasi']
#  [2019 'Jakarta Pusat' 'Menteng' 'farmasi']
#  [2019 'Jakarta Pusat' 'Tanah Abang' 'farmasi']
#  [2019 'Jakarta Pusat' 'Kemayoran' 'farmasi']
#  [2019 'Jakarta Pusat' 'Senen' 'farmasi']
#  [2019 'Jakarta Pusat' 'Sawah Besar' 'farmasi']
#  [2019 'Jakarta Pusat' 'Gambir' 'farmasi']
#  [2019 'Jakarta Barat' 'KEMBANGAN' 'farmasi']
#  [2019 'Jakarta Barat' 'KEBON JERUK' 'farmasi']
#  [2019 'Jakarta Barat' 'PALMERAH' 'farmasi']
#  [2019 'Jakarta Barat' 'GROGOL PETAMBURAN' 'farmasi']
#  [2019 'Jakarta Barat' 'TAMBORA' 'farmasi']
#  [2019 'Jakarta Barat' 'TAMAN SARI' 'farmasi']
#  [2019 'Jakarta Barat' 'CENGKARENG' 'farmasi']
#  [2019 'Jakarta Barat' 'KALIDERES' 'farmasi']
#  [2019 'Jakarta Utara' 'Penjaringan' 'farmasi']
#  [2019 'Jakarta Utara' 'Pademangan' 'farmasi']
#  [2019 'Jakarta Utara' 'Tanjung Priok' 'farmasi']
#  [2019 'Jakarta Utara' 'Koja' 'farmasi']
#  [2019 'Jakarta Utara' 'Kelapa Gading' 'farmasi']
#  [2019 'Jakarta Utara' 'Cilincing' 'farmasi']
#  [2019 'Kepulauan Seribu' 'KEPULAUAN SERIBU UTARA' 'ahli_gizi']
#  [2019 'Kepulauan Seribu' 'KEPULAUAN SERIBU SELATAN' 'ahli_gizi']
#  [2019 'Jakarta Selatan' 'CILANDAK' 'ahli_gizi']
#  [2019 'Jakarta Selatan' 'JAGAKARSA ' 'ahli_gizi']
#  [2019 'Jakarta Selatan' 'KEBAYORAN BARU' 'ahli_gizi']
#  [2019 'Jakarta Selatan' 'KEBAYORAN LAMA' 'ahli_gizi']
#  [2019 'Jakarta Selatan' 'MAMPANG PRAPATAN' 'ahli_gizi']
#  [2019 'Jakarta Selatan' 'PANCORAN' 'ahli_gizi']
#  [2019 'Jakarta Selatan' 'PASAR MINGGU' 'ahli_gizi']
#  [2019 'Jakarta Selatan' 'PESANGGRAHAN' 'ahli_gizi']
#  [2019 'Jakarta Selatan' 'SETIABUDI' 'ahli_gizi']
#  [2019 'Jakarta Selatan' 'TEBET' 'ahli_gizi']
#  [2019 'Jakarta Timur' 'JATINEGARA' 'ahli_gizi']
#  [2019 'Jakarta Timur' 'MATRAMAN' 'ahli_gizi']
#  [2019 'Jakarta Timur' 'PULOGADUNG' 'ahli_gizi']
#  [2019 'Jakarta Timur' 'CAKUNG' 'ahli_gizi']
#  [2019 'Jakarta Timur' 'DUREN SAWIT' 'ahli_gizi']
#  [2019 'Jakarta Timur' 'KRAMAT JATI' 'ahli_gizi']
#  [2019 'Jakarta Timur' 'MAKASAR' 'ahli_gizi']
#  [2019 'Jakarta Timur' 'CIPAYUNG' 'ahli_gizi']
#  [2019 'Jakarta Timur' 'PASAR REBO' 'ahli_gizi']
#  [2019 'Jakarta Timur' 'CIRACAS' 'ahli_gizi']
#  [2019 'Jakarta Pusat' 'Cempaka Putih' 'ahli_gizi']
#  [2019 'Jakarta Pusat' 'Johar Baru' 'ahli_gizi']
#  [2019 'Jakarta Pusat' 'Menteng' 'ahli_gizi']
#  [2019 'Jakarta Pusat' 'Tanah Abang' 'ahli_gizi']
#  [2019 'Jakarta Pusat' 'Kemayoran' 'ahli_gizi']
#  [2019 'Jakarta Pusat' 'Senen' 'ahli_gizi']
#  [2019 'Jakarta Pusat' 'Sawah Besar' 'ahli_gizi']
#  [2019 'Jakarta Pusat' 'Gambir' 'ahli_gizi']
#  [2019 'Jakarta Barat' 'KEMBANGAN' 'ahli_gizi']
#  [2019 'Jakarta Barat' 'KEBON JERUK' 'ahli_gizi']
#  [2019 'Jakarta Barat' 'PALMERAH' 'ahli_gizi']
#  [2019 'Jakarta Barat' 'GROGOL PETAMBURAN' 'ahli_gizi']
#  [2019 'Jakarta Barat' 'TAMBORA' 'ahli_gizi']
#  [2019 'Jakarta Barat' 'TAMAN SARI' 'ahli_gizi']
#  [2019 'Jakarta Barat' 'CENGKARENG' 'ahli_gizi']
#  [2019 'Jakarta Barat' 'KALIDERES' 'ahli_gizi']
#  [2019 'Jakarta Utara' 'Penjaringan' 'ahli_gizi']
#  [2019 'Jakarta Utara' 'Pademangan' 'ahli_gizi']
#  [2019 'Jakarta Utara' 'Tanjung Priok' 'ahli_gizi']
#  [2019 'Jakarta Utara' 'Koja' 'ahli_gizi']
#  [2019 'Jakarta Utara' 'Kelapa Gading' 'ahli_gizi']
#  [2019 'Jakarta Utara' 'Cilincing' 'ahli_gizi']]
#   (0, 5)	1.0
#   (0, 25)	1.0
#   (0, 52)	1.0
#   (0, 55)	2019.0
#   (1, 5)	1.0
#   (1, 24)	1.0
#   (1, 52)	1.0
#   (1, 55)	2019.0
#   (2, 2)	1.0
#   (2, 8)	1.0
#   (2, 52)	1.0
#   (2, 55)	2019.0
#   (3, 2)	1.0
#   (3, 16)	1.0
#   (3, 52)	1.0
#   (3, 55)	2019.0
#   (4, 2)	1.0
#   (4, 20)	1.0
#   (4, 52)	1.0
#   (4, 55)	2019.0
#   (5, 2)	1.0
#   (5, 21)	1.0
#   (5, 52)	1.0
#   (5, 55)	2019.0
#   (6, 2)	1.0
#   :	:
#   (213, 55)	2019.0
#   (214, 4)	1.0
#   (214, 41)	1.0
#   (214, 50)	1.0
#   (214, 55)	2019.0
#   (215, 4)	1.0
#   (215, 40)	1.0
#   (215, 50)	1.0
#   (215, 55)	2019.0
#   (216, 4)	1.0
#   (216, 49)	1.0
#   (216, 50)	1.0
#   (216, 55)	2019.0
#   (217, 4)	1.0
#   (217, 29)	1.0
#   (217, 50)	1.0
#   (217, 55)	2019.0
#   (218, 4)	1.0
#   (218, 27)	1.0
#   (218, 50)	1.0
#   (218, 55)	2019.0
#   (219, 4)	1.0
#   (219, 12)	1.0
#   (219, 50)	1.0
#   (219, 55)	2019.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0684ea3adcb0> in <module>()
#      32
#      33 # Melakukan split dataset menjadi Training set dan Test set
# ---> 34 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
#      35 print("X_train : ", X_train)
#      36 print("X_test : ", X_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2415         raise ValueError("At least one array required as input")
#    2416
# -> 2417     arrays = indexable(*arrays)
#    2418
#    2419     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     376
#     377     result = [_make_indexable(X) for X in iterables]
# --> 378     check_consistent_length(*result)
#     379     return result
#     380
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     327     """
#     328
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     327     """
#     328
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _num_samples(x)
#     268         if len(x.shape) == 0:
#     269             raise TypeError(
# --> 270                 "Singleton array %r cannot be considered a valid collection." % x
#     271             )
#     272         # Check that shape is returning an integer or default to len
#
# TypeError: Singleton array array(<220x56 sparse matrix of type '<class 'numpy.float64'>'
# 	with 880 stored elements in Compressed Sparse Row format>, dtype=object) cannot be considered a valid collection.
